# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#function loading the dataset and reading the datasets.
data=pd.read_excel('sales_data.xlsx')
#this function is providing the intial five records of the dataset.
data.head()
# Out:
#    CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0          22           124  11986.54                96.67            529.59
# 1          29            82  11025.96               134.46             97.92
# 2          83            43   7259.69               168.83            171.69
# 3          95            44   6992.27               158.92             92.82
# 4         124            55   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2016-12-30        2021-10-24                 14.19
# 1             1.19       2018-03-31        2021-10-24                 15.89
# 2             3.99       2017-11-30        2021-10-24                 33.12
# 3             2.11       2019-04-09        2021-10-24                 21.11
# 4             3.26       2020-10-23        2021-10-24                  6.65
#
# ...

# %%
#finding the number of the coloumn and rows in the given dataset.
data.shape
# Out:
# (5000, 42)

# %%
#thei tail methods is providing the last five rows of the datasetr.
data.tail()
# Out:
#       CustomerID  TOTAL_ORDERS  REVENUE  AVERAGE_ORDER_VALUE  \
# 4995      173946             1   117.49               117.49
# 4996      173987             1   117.49               117.49
# 4997      174004             1   117.49               117.49
# 4998      174038             1   117.49               117.49
# 4999      200783             2    94.14                47.07
#
#       CARRIAGE_REVENUE  AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  \
# 4995              4.99             4.99       2021-04-01        2021-04-01
# 4996              4.99             4.99       2021-04-01        2021-04-01
# 4997              4.99             4.99       2021-04-01        2021-04-01
# 4998              4.99             4.99       2021-04-01        2021-04-01
# 4999              9.94             4.97       2014-06-26        2021-04-01
#
#       AVGDAYSBETWEENORDERS  DAYSSINCELASTORDER  ...  TIME_0000_0600_ORDERS  \
# ...

# %%
customer_data=data[['CustomerID','TOTAL_ORDERS']].drop_duplicates()
customer_data
# Out:
#       CustomerID  TOTAL_ORDERS
# 0             22           124
# 1             29            82
# 2             83            43
# 3             95            44
# 4            124            55
# ...          ...           ...
# 4995      173946             1
# 4996      173987             1
# 4997      174004             1
# 4998      174038             1
# 4999      200783             2
#
# [5000 rows x 2 columns]

# %%
max_x = data.loc[data['TOTAL_ORDERS'].idxmax()]
max_x
# Out:
# CustomerID                                    26
# TOTAL_ORDERS                                 156
# REVENUE                                  11349.6
# AVERAGE_ORDER_VALUE                        72.75
# CARRIAGE_REVENUE                          462.93
# AVERAGESHIPPING                             2.97
# FIRST_ORDER_DATE             2019-10-08 00:00:00
# LATEST_ORDER_DATE            2021-08-28 00:00:00
# AVGDAYSBETWEENORDERS                        4.42
# DAYSSINCELASTORDER                            58
# MONDAY_ORDERS                                 14
# TUESDAY_ORDERS                                15
# WEDNESDAY_ORDERS                              24
# THURSDAY_ORDERS                               32
# FRIDAY_ORDERS                                 21
# SATURDAY_ORDERS                               30
# SUNDAY_ORDERS                                 20
# MONDAY_REVENUE                             987.8
# TUESDAY_REVENUE                          1592.36
# ...

# %%
data.head()
# Out:
#    CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0          22           124  11986.54                96.67            529.59
# 1          29            82  11025.96               134.46             97.92
# 2          83            43   7259.69               168.83            171.69
# 3          95            44   6992.27               158.92             92.82
# 4         124            55   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2016-12-30        2021-10-24                 14.19
# 1             1.19       2018-03-31        2021-10-24                 15.89
# 2             3.99       2017-11-30        2021-10-24                 33.12
# 3             2.11       2019-04-09        2021-10-24                 21.11
# 4             3.26       2020-10-23        2021-10-24                  6.65
#
# ...

# %%
#maximum order finding through/ this makes a user is special use for the organization 
#maximum order is refecting who is using our services is regulary 
data.TOTAL_ORDERS.describe()
# Out:
# count    5000.00000
# mean       12.87040
# std        12.67988
# min         1.00000
# 25%         3.00000
# 50%         8.00000
# 75%        20.00000
# max       156.00000
# Name: TOTAL_ORDERS, dtype: float64

# %%
#find the record for the loyal user a Loyal user who make the maximum orders.
max=156
df=pd.read_excel('sales_data.xlsx')
print(df['TOTAL_ORDERS'].where(df['TOTAL_ORDERS']>=max))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18dd8fd53ecc> in <module>
#       1 #find the record for the loyal user a Loyal user who make the maximum orders.
#       2 max=156
# ----> 3 print(data['TOTAL_ORDERS'].where(['TOTAL_ORDERS']>=max))
#
# NameError: name 'data' is not defined
